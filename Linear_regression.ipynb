# %% [markdown]
# # Linear Regression
# ###

# %% [markdown]
# ## Modelling the relationship between Housing expenses and various factors
#
# ##

# %% [markdown]
# ## Project Overview
# #### In this project, we aim to build a simple Linear regression model to predict Housing prices based on multiple features. By analyzing the relationship between housing prices and features such as area,bedrooms,bathrooms,parking etc, we can provide valuable insights for Buyers so that they can have a rough idea of the property's evaluation.

# %% [markdown]
# ### Supervised machine learning algorithms are of 2 types:
# * Regression
# * Classification

# %% [markdown]
# ##### Within the Regression Category, there comes linear and logistic regression, which are used for predicting continuous values and probabilities, respectively. In this project, we will discuss about Linear Regression in detail.

# %% [markdown]
# ##### Linear Regression is a type of supervised machine learning algorithm used for predicting continuous values. It establishes a relationship between the dependent variable(target) and one or more independent variables(features) using a linear equation. The goal is to find the best-fitting line (regression line) that minimizes the difference between the predicted and actual values.
# ##### Basically, its learns from labelled datasets and maps the data points with most optimised linear functions which can be used for prediction on a completely new datasets. It assumes that there is a "Linear" relation between the input and output meaning the output changes at a constant rate as the input changes. Therefore their relationship is depicted with a straight line.

# %% [markdown]
# ### Implementation Steps
# 1. Data Collection
# 2. Data Preprocessing
# 3. Model Training
# 4. Model Evaluation
# 5. Prediction

# %% [markdown]
# #### A nice example of linear regression would be predicting the price of an iteam based on the cost of advertisement.
# * Dependent Variable (Target):    Sales of the product (in rupees)
# * Independent Variable (Feature):    Money spent on Advertisement (in rupees)

# %% [markdown]
# ## BEST FIT LINE

# %% [markdown]
# ##### In Linear Regression, a Best Fit Line is a straight line that best represents the relationship between the independent and dependent variables in a dataset. It is used to predict the value of the dependent variable based on the value of the independent variable. The line is determined by minimizing the sum of the squared differences between the observed values and the values predicted by the line, a method known as Least Squares which we will talk about in detail later. The Best Fit Line helps in understanding trends, making predictions, and identifying correlations within the data.

# %% [markdown]
# ![Best Fit Line](1.png)
# ##### Figure 1

# %% [markdown]
# #### Here Y is the dependent variable and X is the independent variable which is also called the predictor of Y since it is predicting the value of Y.

# %% [markdown]
# ### Equation of the best fit line

# %% [markdown]
# ##### For simple linear regression (with one independent variable), the best-fit line is represented by the equation
# ##### y = mx + b
# * y is the predicted value(dependent variable)
# * x is the input value(independent variable)
# * m is the slope of the line(change in y with respect to x)
# * b is the intercept value of y(when x=0)

# %% [markdown]
# #### Note: The best fit Line optimises the data(values of m and b) such that the predicted values of y are as close as possible to the real values

# %% [markdown]
# ## COST FUNCTION

# %% [markdown]
# ##### It is not easy to get the above discussed best fit line in real world cases due to the existence of errors. Therefore we need to calculate the errors which effects it. These errors are required to make a more accurate prediction of the value of the dependent variable.
#
# ##### The difference between the predicted value ŷ and the true value y and it is called Cost Function or the Loss Function.

# %% [markdown]
# ##### In a regression model, we try to minimize the residuals by finding the line of best fit. The residuals are represented by the vertical dotted lines from actual data points to the line.
#
# ##### We can try to minimize the sum of the residuals, but then a large positive residual would cancel out a large negative residual. For this reason, we minimize the sum of the squares of the residuals.
#
# ##### Mathematically, residual for a data point i would be given as
# ##### di = yi - ŷi
#
# ##### Sum of Square od residuals is given as
# ##### D = Ʃ di^2

# %% [markdown]
# ##### This is the **Cost Function** which denotes the total error present in the model which is nothing but the sum of total errors of each individual data point. This method of finding the parameters of model and thus the regression line is called the Least Square Method.
# ##### We will use it to predict the Target using only 1 Feature so in this case we can call this method **Ordinary Least Square Method**

# %% [markdown]
# ## Problem Statement
# #### The goal of this project is to develop a linear regression model that can accurately predict house prices based on the provided key features in the dataset. We will explore the dataset, preprocess the data, and build a model to identify the key factors influencing sales performance.

# %% [markdown]
# ## Software Information
# #### I made this project on Jupyter notebook, running on base(Python 3.13.5) using VS Code

# %% [markdown]
# ## Python Libraries

# %% [markdown]
# ##### The basic Python Libraries I used in this project are:
# • Numpy – It provides a fast numerical array structure and operating functions.
#
# • pandas – It provides tools for data storage, manipulation and analysis tasks.
#
# • Scikit-Learn – The required machine learning library in Python.
#
# • Matplotlib – It is the basic plotting library in Python. It provides tools for making plots.
#
# • Seaborn – It is used for statistical data visualisation.
#
# • Warnings – To handle Warnings

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
#It means that the output of the plotting commands are displayed inline in Jupyter notebook.

# %% [markdown]
# ### Dataset
# #### The dataset used in this project contains information about retail sales and customer informaion across different channels. The key features include:
# - `price`: Price of the house
# - `area`: Area of the property in square feet
# - `bedrooms`: Number of bedrooms on the property
# - `bathrooms`: Number of bathrooms on the property
# - `stories`: Number of stories of the property
# - `mainroad`: Whether the property is on main road or not
# - `guestroom`: Does the property possess a guestroom
# - `basement`: Does the property possess a basement
# - `hotwaterheating`: Does the property possess water heating facility
# - `airconditioning`: Does the property possess air conditioning
# - `parking`: Does the property possess a parking spot
# - `prefarea`: Does the property possess a pref area
# - `furnishingstatus`: Is the property furnished or not
#
# The dataset will be loaded and explored to understand the relationships between these variables.

# %%
df=pd.read_csv("Housing.csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# ## Exploratory data analysis
# ##### First, I import the dataset into the dataframe with the standard read_csv () function of pandas library and assign it to the df variable. Then, I conducted exploratory data analysis to get a feel for the data

# %% [markdown]
# ### Using Multiple Methods to Analyze the Data

# %%
#Views the dimensions of the dataframe in the form of (rows,columns)

df.shape
# Out:
# (545, 14)

# %%
#Views the top 5 rows of the dataframe.
#you can input a value within head() to change the number of rows displayed.

df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.head(10) #Like this
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
#Used in the same way as the head() but displays the last few rows of the dataframe.

df.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
#Gives the names of columns in the dataframe

df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
#Used to rename the columns of a dataframe. Remember to only input the exact number of new column names as there are existing columns.
#I used the same names since I do not want to change the already accurate column names.
df.columns = ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'parking', 'prefarea', 'furnishingstatus']
df.head() #to view the renames columns
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
#Provides a concise summary of the dataframe, including the number of non-null entries, data types, and memory usage.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
# Displays descriptive statistics

df.describe()

# mean = median=mode meaning this is a normal distribution
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# ##### Now that I have got the feel of the dataset, lets visualise the data to get more insights.

# %%
#Boxplot is used to visualise the data in a graphical format and shows the presence or absense of outliers.
#No Outliers present means no significant deviation from mean but here Outliers are present meaning there are deviations
df.boxplot(column='price')
plt.show()

# %% [markdown]
# ## Independent and Dependent Variables
# In this project, I refer Independent variable as Feature variable and Dependent variable as Target variable. These variables are also recognized by different names as follows:-
#
# ### Independent variable
# Independent variable is also called Input variable and is denoted by X. In practical applications, independent variable is also called Feature variable or Predictor variable. We can denote it as:-
#
# Independent or Input variable (X) = Feature variable = Predictor variable
#
# ### Dependent variable
# Dependent variable is also called Output variable and is denoted by y.
#
# Dependent variable is also called Target variable or Response variable. It can be denoted it as follows:-
#
# Dependent or Output variable (y) = Target variable = Response variable

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
#Inorder to create a new feature 'Feature' which is a weighted sum of existing features

df['Feature'] = df['area']*0.8+ df['bedrooms']*0.5+df['bathrooms']*0.4+df['parking']*0.2+df['stories']*0.1
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
#Decalre feature and target variables


X=df['Feature'].values
y=df['price'].values

#In this dataset, 'Quantity' and 'Price per Unit' are the independent variable (feature) and 'Total Amount' is the dependent variable (target).
#values method stores the values of these columns as numpy arrays

# %%
## Visual Exploratory Data Analysis
#Plot scatter plot between X and y
plt.scatter(X,y,color='#006994',label='Scatter Plot')
plt.xlabel('Feature')
plt.ylabel('Price')
plt.title('Relationship between Price per Unit and Price')
plt.legend(loc=0)
plt.show()

# %%
#Checking the dimensions of X and y to ensure that they are in the right format for Scikit-Learn API
#It is an important precursor to model building
print(X.shape)
print(y.shape)
# Out:
# (545,)
# (545,)

# %% [markdown]
# ## Reshaping X and y

# %% [markdown]
# Since we are working with only one feature variable, so we need to reshape using Numpy reshape() method.
#
# It specifies first dimension to be -1, which means "unspecified".
#
# Its value is inferred from the length of the array and the remaining dimensions

# %%
X =X.reshape(-1,1)
y=y.reshape(-1,1)
print(X.shape)
print(y.shape)
# Getting the feature and target variable right is an important precursor to model building
# Out:
# (545, 1)
# (545, 1)

# %% [markdown]
# ## Splitting dataset

# %% [markdown]
# Spliting the data into 2 parts namely- train and test sets
# The model learns their relationship from the training data and predicts on test data.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (381, 1)
# (381, 1)
# (164, 1)
# (164, 1)

# %% [markdown]
# # Mechanics of the Model
# After Splitting the data into training and testing sets in the ratio 70:30, we can now proceed to build the linear regression model using the training data.
# Now the model is ready to make predictions on the test data (X_test). Hence, I predict on the test data using the predict method

# %%
# Fit the Linear Model
from sklearn.linear_model import LinearRegression
lm=LinearRegression()

#Training the model using training datasets
lm.fit(X_train,y_train)
# Prediction on test data
y_pred=lm.predict(X_test)

# %% [markdown]
# ## Model slope and intercept term

# %%
#The model slope is given by lm.coef_ and model intercept is given by lm.intercept_
print("Model slope:", lm.coef_) #=y
print("Model intercept:", lm.intercept_)#=x
# Out:
# Model slope: [[561.90951493]]
# Model intercept: [2455757.98031195]

# %% [markdown]
# ##### Therefore y=561.90951493 and x=2455757.98031195

# %% [markdown]
# ## Predictions

# %% [markdown]
# I have predicted the Advertising values on first five 5 datasets by writing code
#
#     lm.predict(X) [0:5]
#
# If I remove [0:5], then I will bascially be predicting the values for the enitre database.
#
# To make prediction, on an individual Sales value, we use
#
# 	lm.predict(Xi)
#
# where Xi is the retail_sales data value of the ith observation

# %%
lm.predict(X) [0:5]
# Out:
# array([[5793219.54423965],
#        [6486110.16710003],
#        [6934682.53286878],
#        [5829237.94414667],
#        [5792938.58948218]])

# %%
print(str(lm.predict([[2]])))


# The prediction for [[2]] is within the range of the training data, making it a reliable estimate. If we took a value outside this range, the prediction might be less reliable.
# Out:
# [[2456881.79934181]]

# %% [markdown]
# ## Regression Metrics for model performance

# %% [markdown]
# ##### For problems involing a regression model, there are 2 main ways to compute model performance. They are:-
# * RMSE (Root Mean Square Error)
# * R-Squared Value

# %% [markdown]
# ## RMSE

# %% [markdown]
# ##### RMSE is the standard deviation of the residuals (prediction errors). It provides a measure of how well the model's predictions match the actual data.
# ##### It is calculated as the square root of the average of the squared differences between predicted and actual values.
# ##### RMSE is an absolute measure of fit. It gives us how spread the residuals are, given by the standard deviation of the residuals. The more concentrated the data is around the regression line, the lower the residuals and hence lower the standard deviation of residuals. It results in lower values of RMSE.    So, comparatively lower values of RMSE indicate better fit of data.

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test, y_pred)
rmse=np.sqrt(mse)
print("RMSE value: {:.4f}".format(rmse))
# Out:
# RMSE value: 1786995.8456

# %%
print(y.mean(),y.std())
# Out:
# 4766729.247706422 1868722.8281312082

# %%
nrmse=rmse/y.mean()
print(nrmse)
# Out:
# 0.374889311472546

# %% [markdown]
# ##### This means my error % is around 37.4% which is alright for my first ML project

# %% [markdown]
# ## R2 Score
# ##### R2 Score is another metric to evaluate performance of a regression model. It is also called coefficient of determination. It gives us an idea of goodness of fit for the linear regression models. It indicates the percentage of variance that is explained by the model.
#
# ##### Mathematically,
#
#     R2 Score = Explained Variation/Total Variation
#
# ###### In general, the higher the R2 Score value, the better the model fits the data. Usually, its value ranges from 0 to 1. So, we want its value to be as close to 1. Its value can become negative if our model is wrong.

# %%
from sklearn.metrics import r2_score
print ("R2 Score value: {:.4f}".format(r2_score(y_test, y_pred)))
# Out:
# R2 Score value: 0.2585

# %% [markdown]
# ##### My R2 Value is  not good and indicates that the model does not explain a significant portion of the variance in the target variable.

# %% [markdown]
# ## Interpretation and Conclusion
# ##### The RMSE value has been found to be 1786995.8456 . It means the standard deviation for our prediction is 1786995.8456. So, sometimes we expect the predictions to be off by more than 1786995.8456 and other times we expect less than 1786995.8456. So, the model is not good fit to the data.
#
# ##### In business decisions, the benchmark for the R2 score value is 0.7. It means if R2 score value >= 0.7, then the model is good enough to deploy on unseen data whereas if R2 score value < 0.7, then the model is not good enough to deploy. Our R2 score value has been found to be 0.2585. It means that this model explains 25.85 % of the variance in our dependent variable. So, the R2 score value confirms that the model is not good enough to deploy because it does not provide good fit to the data.

# %%
plt.scatter(X, y, color = 'blue', label='Scatter Plot')
plt.plot(X_test, y_pred, color = 'black', linewidth=3, label = 'Regression Line')
plt.title('Relationship Housing prices and multiple Features')
plt.xlabel('Features')
plt.ylabel('Housing Prices')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ## Residual analysis
# A linear regression model may not represent the data appropriately. The model may be a poor fit to the data. So, we should validate our model by defining and examining residual plots.
#
# The difference between the observed value of the dependent variable (y) and the predicted value (ŷi) is called the residual and is denoted by e. The scatter-plot of these residuals is called residual plot.
#
# If the data points in a residual plot are randomly dispersed around horizontal axis and an approximate zero residual mean, a linear regression model may be appropriate for the data. Otherwise a non-linear model may be more appropriate.
#
# If we take a look at the generated ‘Residual errors’ plot, we can clearly see that the train data plot pattern is non-random. Same is the case with the test data plot pattern. So, it suggests a better-fit for a non-linear model.

# %%
# Plotting residual errors

plt.scatter(lm.predict(X_train), lm.predict(X_train) - y_train, color = 'red', label = 'Train data')
plt.scatter(lm.predict(X_test), lm.predict(X_test) - y_test, color = 'blue', label = 'Test data')
plt.hlines(xmin = 0, xmax = 10000000, y = 0, linewidth = 3)
plt.title('Residual errors')
plt.legend(loc = 4)
plt.show()

# %% [markdown]
# ## Checking for Overfitting and Underfitting

# %% [markdown]
# I calculate training set score as 0.3042. Similarly, I calculate test set score as 0.2585. The training set score is very poor. So, the model does not learn the relationships appropriately from the training data. Thus, the model performs poorly on the training data. It is a clear sign of Underfitting. Hence, I validated my finding that the linear regression model does not provide good fit to the data.
#
# Underfitting means our model performs poorly on the training data. It means the model does not capture the relationships between the training data. This problem can be improved by increasing model complexity. We should use more powerful models like Polynomial regression to increase model complexity.

# %%
print("Training set score: {:.4f}".format(lm.score(X_train,y_train)))

print("Test set score: {:.4f}".format(lm.score(X_test,y_test)))
# Out:
# Training set score: 0.3042
# Test set score: 0.2585

# %% [markdown]
# ## Simple Linear Regression - Model Assumptions
# ##### The Linear Regression Model is based on several assumptions which are listed below:-
#
#     i. Linear relationship ii. Multivariate normality iii. No or little multicollinearity iv. No auto-correlation v. Homoscedasticity
#
# ### i. Linear relationship
# The relationship between response and feature variables should be linear. This linear relationship assumption can be tested by plotting a scatter-plot between response and feature variables.
#
# ### ii. Multivariate normality
# The linear regression model requires all variables to be multivariate normal. A multivariate normal distribution means a vector in multiple normally distributed variables, where any linear combination of the variables is also normally distributed.
#
# ### iii. No or little multicollinearity
# It is assumed that there is little or no multicollinearity in the data. Multicollinearity occurs when the features (or independent variables) are highly correlated.
#
# ### iv. No auto-correlation
# Also, it is assumed that there is little or no auto-correlation in the data. Autocorrelation occurs when the residual errors are not independent from each other.
#
# ### v. Homoscedasticity
# Homoscedasticity describes a situation in which the error term (that is, the noise in the model) is the same across all values of the independent variables. It means the residuals are same across the regression line. It can be checked by looking at scatter plot.

# %% [markdown]
# ## References
# ##### This project is highly inspired from the following sources and sites:-
# i. https://www.geeksforgeeks.org/machine-learning/ml-linear-regression/
#
# ii. https://github.com/pb111/Simple-Linear-Regression-Project/blob/master/SLRProject.ipynb
#
# iii. https://en.wikipedia.org/wiki/Linear_regression

# %% [markdown]
# ### Lastly, I would like to Thank my mentor from Launched Global, Sruthi Tarimana Maam for giving me the opportunity to work on this project and for her invaluable guidance throughout the process.
